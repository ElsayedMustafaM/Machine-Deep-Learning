# %%
# Load the Drive helper and mount
from google.colab import drive
# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install apyori
from apyori import apriori
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVR
import math
from sklearn import metrics
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error,accuracy_score
# Out:
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-cp36-none-any.whl size=5975 sha256=c9e7941fee572bf8fe44f3e677b7a3ccf2945d0e9b4e0290cafe676111c594e6
#   Stored in directory: /root/.cache/pip/wheels/5d/92/bb/474bbadbc8c0062b9eb168f69982a0443263f8ab1711a8cad0
# Successfully built apyori
# ...

# %%
h5_ch_1=pd.read_csv('drive/My Drive/house_5/channel_1.dat',delim_whitespace=True,header=None)
h5_ch_2=pd.read_csv('drive/My Drive/house_5/channel_2.dat',delim_whitespace=True,header=None)
h5_ch_3=pd.read_csv('drive/My Drive/house_5/channel_3.dat',delim_whitespace=True,header=None)
h5_ch_4=pd.read_csv('drive/My Drive/house_5/channel_4.dat',delim_whitespace=True,header=None)
h5_ch_5=pd.read_csv('drive/My Drive/house_5/channel_5.dat',delim_whitespace=True,header=None)
h5_ch_6=pd.read_csv('drive/My Drive/house_5/channel_6.dat',delim_whitespace=True,header=None)
h5_ch_7=pd.read_csv('drive/My Drive/house_5/channel_7.dat',delim_whitespace=True,header=None)
h5_ch_8=pd.read_csv('drive/My Drive/house_5/channel_8.dat',delim_whitespace=True,header=None)
h5_ch_9=pd.read_csv('drive/My Drive/house_5/channel_9.dat',delim_whitespace=True,header=None)
h5_ch_10=pd.read_csv('drive/My Drive/house_5/channel_10.dat',delim_whitespace=True,header=None)
h5_ch_11=pd.read_csv('drive/My Drive/house_5/channel_11.dat',delim_whitespace=True,header=None)
h5_ch_12=pd.read_csv('drive/My Drive/house_5/channel_12.dat',delim_whitespace=True,header=None)
h5_ch_13=pd.read_csv('drive/My Drive/house_5/channel_13.dat',delim_whitespace=True,header=None)
h5_ch_14=pd.read_csv('drive/My Drive/house_5/channel_14.dat',delim_whitespace=True,header=None)
h5_ch_15=pd.read_csv('drive/My Drive/house_5/channel_15.dat',delim_whitespace=True,header=None)
h5_ch_16=pd.read_csv('drive/My Drive/house_5/channel_16.dat',delim_whitespace=True,header=None)
h5_ch_17=pd.read_csv('drive/My Drive/house_5/channel_17.dat',delim_whitespace=True,header=None)
h5_ch_18=pd.read_csv('drive/My Drive/house_5/channel_18.dat',delim_whitespace=True,header=None)
h5_ch_19=pd.read_csv('drive/My Drive/house_5/channel_19.dat',delim_whitespace=True,header=None)
h5_ch_20=pd.read_csv('drive/My Drive/house_5/channel_20.dat',delim_whitespace=True,header=None)
h5_ch_21=pd.read_csv('drive/My Drive/house_5/channel_21.dat',delim_whitespace=True,header=None)
h5_ch_22=pd.read_csv('drive/My Drive/house_5/channel_22.dat',delim_whitespace=True,header=None)
h5_ch_23=pd.read_csv('drive/My Drive/house_5/channel_23.dat',delim_whitespace=True,header=None)
h5_ch_24=pd.read_csv('drive/My Drive/house_5/channel_24.dat',delim_whitespace=True,header=None)
h5_ch_25=pd.read_csv('drive/My Drive/house_5/channel_25.dat',delim_whitespace=True,header=None)
h5_labels=pd.read_csv('drive/My Drive/house_5/labels.dat',delim_whitespace=True,header=None)

# %%
h5_ch_2_button_press=pd.read_csv('drive/My Drive/house_5/channel_2_button_press.dat',delim_whitespace=True,header=None)
h5_ch_3_button_press=pd.read_csv('drive/My Drive/house_5/channel_3_button_press.dat',delim_whitespace=True,header=None)
h5_ch_5_button_press=pd.read_csv('drive/My Drive/house_5/channel_5_button_press.dat',delim_whitespace=True,header=None)
h5_ch_6_button_press=pd.read_csv('drive/My Drive/house_5/channel_6_button_press.dat',delim_whitespace=True,header=None)
h5_ch_7_button_press=pd.read_csv('drive/My Drive/house_5/channel_7_button_press.dat',delim_whitespace=True,header=None)
h5_ch_9_button_press=pd.read_csv('drive/My Drive/house_5/channel_9_button_press.dat',delim_whitespace=True,header=None)
h5_ch_11_button_press=pd.read_csv('drive/My Drive/house_5/channel_11_button_press.dat',delim_whitespace=True,header=None)
h5_ch_12_button_press=pd.read_csv('drive/My Drive/house_5/channel_12_button_press.dat',delim_whitespace=True,header=None)
h5_ch_13_button_press=pd.read_csv('drive/My Drive/house_5/channel_13_button_press.dat',delim_whitespace=True,header=None)
h5_ch_16_button_press=pd.read_csv('drive/My Drive/house_5/channel_16_button_press.dat',delim_whitespace=True,header=None)
h5_ch_17_button_press=pd.read_csv('drive/My Drive/house_5/channel_17_button_press.dat',delim_whitespace=True,header=None)
h5_ch_25_button_press=pd.read_csv('drive/My Drive/house_5/channel_25_button_press.dat',delim_whitespace=True,header=None)

# %%
print(h5_ch_17_button_press)
# Out:
#             0  1
# 0  1407110311  0
# 1  1407110323  1
# 2  1407110390  0
# 3  1407110396  1

# %%
print("channel 14 : ")
h5_ch_14.head(5)
# Out:
# channel 14 :
#             0   1
# 0  1404059031  23
# 1  1404059037  22
# 2  1404059044  22
# 3  1404059050  22
# 4  1404059056  22

# %%
h5_ch_1.columns=['time','power_demand']
h5_ch_2.columns=['time','power_demand']
h5_ch_3.columns=['time','power_demand']
h5_ch_4.columns=['time','power_demand']
h5_ch_5.columns=['time','power_demand']
h5_ch_6.columns=['time','power_demand']
h5_ch_7.columns=['time','power_demand']
h5_ch_8.columns=['time','power_demand']
h5_ch_9.columns=['time','power_demand']
h5_ch_10.columns=['time','power_demand']
h5_ch_11.columns=['time','power_demand']
h5_ch_12.columns=['time','power_demand']
h5_ch_13.columns=['time','power_demand']
h5_ch_14.columns=['time','power_demand']
h5_ch_15.columns=['time','power_demand']
h5_ch_16.columns=['time','power_demand']
h5_ch_17.columns=['time','power_demand']
h5_ch_18.columns=['time','power_demand']
h5_ch_19.columns=['time','power_demand']
h5_ch_20.columns=['time','power_demand']
h5_ch_21.columns=['time','power_demand']
h5_ch_22.columns=['time','power_demand']
h5_ch_23.columns=['time','power_demand']
h5_ch_24.columns=['time','power_demand']
h5_ch_25.columns=['time','power_demand']


h5_ch_10.head(4)
# Out:
#          time  power_demand
# 0  1404059032            28
# 1  1404059038            28
# 2  1404059042            29
# 3  1404059048            28

# %% [markdown]
# #Convert Number To TimeStamp

# %%
h5_ch_1['time']=pd.to_datetime(h5_ch_1['time'], unit='s')
h5_ch_2['time']=pd.to_datetime(h5_ch_2['time'], unit='s')
h5_ch_3['time']=pd.to_datetime(h5_ch_3['time'], unit='s')
h5_ch_4['time']=pd.to_datetime(h5_ch_4['time'], unit='s')
h5_ch_5['time']=pd.to_datetime(h5_ch_5['time'], unit='s')
h5_ch_6['time']=pd.to_datetime(h5_ch_6['time'], unit='s')
h5_ch_7['time']=pd.to_datetime(h5_ch_7['time'], unit='s')
h5_ch_8['time']=pd.to_datetime(h5_ch_8['time'], unit='s')
h5_ch_9['time']=pd.to_datetime(h5_ch_9['time'], unit='s')
h5_ch_10['time']=pd.to_datetime(h5_ch_10['time'], unit='s')
h5_ch_11['time']=pd.to_datetime(h5_ch_11['time'], unit='s')
h5_ch_12['time']=pd.to_datetime(h5_ch_12['time'], unit='s')
h5_ch_13['time']=pd.to_datetime(h5_ch_13['time'], unit='s')
h5_ch_14['time']=pd.to_datetime(h5_ch_14['time'], unit='s')
h5_ch_15['time']=pd.to_datetime(h5_ch_15['time'], unit='s')
h5_ch_16['time']=pd.to_datetime(h5_ch_16['time'], unit='s')
h5_ch_17['time']=pd.to_datetime(h5_ch_17['time'], unit='s')
h5_ch_18['time']=pd.to_datetime(h5_ch_18['time'], unit='s')
h5_ch_19['time']=pd.to_datetime(h5_ch_19['time'], unit='s')
h5_ch_20['time']=pd.to_datetime(h5_ch_20['time'], unit='s')
h5_ch_21['time']=pd.to_datetime(h5_ch_21['time'], unit='s')
h5_ch_22['time']=pd.to_datetime(h5_ch_22['time'], unit='s')
h5_ch_23['time']=pd.to_datetime(h5_ch_23['time'], unit='s')
h5_ch_24['time']=pd.to_datetime(h5_ch_24['time'], unit='s')
h5_ch_25['time']=pd.to_datetime(h5_ch_25['time'], unit='s')

# %%
print ("channel 14 : ")
h5_ch_14.head(5)
# Out:
# channel 14 :
#                  time  power_demand
# 0 2014-06-29 16:23:51            23
# 1 2014-06-29 16:23:57            22
# 2 2014-06-29 16:24:04            22
# 3 2014-06-29 16:24:10            22
# 4 2014-06-29 16:24:16            22

# %%
h5_labels
# Out:
#      0                         1
# 0    1                 aggregate
# 1    2   stereo_speakers_bedroom
# 2    3                i7_desktop
# 3    4                 hairdryer
# 4    5                primary_tv
# 5    6       24_inch_lcd_bedroom
# 6    7                 treadmill
# 7    8  network_attached_storage
# 8    9              core2_server
# 9   10               24_inch_lcd
# 10  11                       PS4
# 11  12                steam_iron
# 12  13           nespresso_pixie
# 13  14                   atom_pc
# 14  15                   toaster
# 15  16          home_theatre_amp
# 16  17                sky_hd_box
# 17  18                    kettle
# 18  19            fridge_freezer
# 19  20                      oven
# 20  21              electric_hob
# 21  22                dishwasher
# 22  23                 microwave
# 23  24              washer_dryer
# 24  25            vacuum_cleaner

# %% [markdown]
# # Visualizing Appliances

# %%
plt.figure(figsize=(18,5))
plt.plot(h5_ch_1['time'],h5_ch_1['power_demand'])
plt.title('aggregate')
plt.figure(figsize=(18,5))
plt.plot(h5_ch_2['time'],h5_ch_2['power_demand'])
plt.title('stereo_speakers_bedroom')
plt.figure(figsize=(18,5))
plt.plot(h5_ch_3['time'],h5_ch_3['power_demand'])
plt.title('i7_desktop')
plt.figure(figsize=(18,5))
plt.plot(h5_ch_4['time'],h5_ch_4['power_demand'])
plt.title('hairdryer')
plt.figure(figsize=(18,5))
plt.plot(h5_ch_5['time'],h5_ch_5['power_demand'])
plt.title('primary_tv')
plt.figure(figsize=(18,5))
plt.plot(h5_ch_6['time'],h5_ch_6['power_demand'])
plt.title('24_inch_lcd_bedroom')
plt.figure(figsize=(18,5))
plt.plot(h5_ch_7['time'],h5_ch_7['power_demand'])
plt.title('treadmilltreadmill')
plt.figure(figsize=(18,5))
plt.plot(h5_ch_8['time'],h5_ch_8['power_demand'])
plt.title('network_attached_storage')
plt.figure(figsize=(18,5))
plt.plot(h5_ch_9['time'],h5_ch_9['power_demand'])
plt.title('core2_server')
plt.figure(figsize=(18,5))
plt.plot(h5_ch_10['time'],h5_ch_10['power_demand'])
plt.title('24_inch_lcd')
plt.figure(figsize=(18,5))
plt.plot(h5_ch_11['time'],h5_ch_11['power_demand'])
plt.title('PS4')
plt.figure(figsize=(18,5))
plt.plot(h5_ch_12['time'],h5_ch_12['power_demand'])
plt.title('steam_iron')
plt.figure(figsize=(18,5))
plt.plot(h5_ch_13['time'],h5_ch_13['power_demand'])
plt.title('nespresso_pixie')
plt.figure(figsize=(18,5))
plt.plot(h5_ch_14['time'],h5_ch_14['power_demand'])
plt.title('atom_pc')
plt.figure(figsize=(18,5))
plt.plot(h5_ch_15['time'],h5_ch_15['power_demand'])
plt.title('toaster')
plt.figure(figsize=(18,5))
plt.plot(h5_ch_16['time'],h5_ch_16['power_demand'])
plt.title('home_theatre_amp')
plt.figure(figsize=(18,5))
plt.plot(h5_ch_17['time'],h5_ch_17['power_demand'])
plt.title('sky_hd_box')
plt.figure(figsize=(18,5))
plt.plot(h5_ch_18['time'],h5_ch_18['power_demand'])
plt.title('kettle')
plt.figure(figsize=(18,5))
plt.plot(h5_ch_19['time'],h5_ch_19['power_demand'])
plt.title('fridge_freezer')
plt.figure(figsize=(18,5))
plt.plot(h5_ch_20['time'],h5_ch_20['power_demand'])
plt.title('oven')
plt.figure(figsize=(18,5))
plt.plot(h5_ch_21['time'],h5_ch_21['power_demand'])
plt.title('electric_hob')
plt.figure(figsize=(18,5))
plt.plot(h5_ch_22['time'],h5_ch_22['power_demand'])
plt.title('dishwasher')
plt.figure(figsize=(18,5))
plt.plot(h5_ch_23['time'],h5_ch_23['power_demand'])
plt.title('microwave')
plt.figure(figsize=(18,5))
plt.plot(h5_ch_24['time'],h5_ch_24['power_demand'])
plt.title('washer_dryer')
plt.figure(figsize=(18,5))
plt.plot(h5_ch_25['time'],h5_ch_25['power_demand'])
plt.title('vacuum_cleaner')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:61: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# ...

# %%
labels=['stereo_speakers_bedroom','i7_desktop','hairdryer','primary_tv','24_inch_lcd_bedroom','treadmill','network_attached_storage'
         ,'core2_server','24_inch_lcd','PS4','steam_iron','nespresso_pixie','atom_pc','toaster', 'home_theatre_amp','sky_hd_box'
            ,'kettle','fridge_freezer','oven','electric_hob','dishwasher','microwave','washer_dryer','vacuum_cleanervacuum_cleaner']


res=[h5_ch_2['power_demand'].mean(),h5_ch_3['power_demand'].mean(),h5_ch_4['power_demand'].mean(),h5_ch_5['power_demand'].mean()
   ,h5_ch_6['power_demand'].mean(),h5_ch_7['power_demand'].mean(),h5_ch_8['power_demand'].mean(),h5_ch_9['power_demand'].mean(),
    h5_ch_10['power_demand'].mean(),h5_ch_11['power_demand'].mean(),h5_ch_12['power_demand'].mean(),h5_ch_13['power_demand'].mean(),
    h5_ch_14['power_demand'].mean(),h5_ch_15['power_demand'].mean(),h5_ch_16['power_demand'].mean(),h5_ch_17['power_demand'].mean(),
    h5_ch_18['power_demand'].mean(),h5_ch_19['power_demand'].mean(), h5_ch_20['power_demand'].mean(),h5_ch_21['power_demand'].mean(),
     h5_ch_22['power_demand'].mean(),h5_ch_23['power_demand'].mean(),h5_ch_24['power_demand'].mean(),h5_ch_25['power_demand'].mean()]
x = [i for i in range(1,25)]
plt.figure(figsize=(18,5))
plt.bar(x,res)
plt.xticks(x, labels,rotation=45)
plt.ylabel('Mean_power_demand')
plt.xlabel('Appliances')
plt.title('Power_demand of Appliances')
# Out:
# Text(0.5, 1.0, 'Power_demand of Appliances')

# %% [markdown]
# #Power Consumption For One Day

# %%
labels=['stereo_speakers_bedroom : \n'+str(round(res[0],3)),'i7_desktop : \n'+str(round(res[0],3)),'hairdryer : \n'+str(round(res[0],3)),
        'primary_tv : \n'+str(round(res[0],3)),'24_inch_lcd_bedroom : \n'+str(round(res[0],3)),'treadmill : \n'+str(round(res[0],3)),
         'network_attached_storage : \n'+str(round(res[0],3)),'core2_server : \n'+str(round(res[0],3)),'24_inch_lcd : \n'+str(round(res[0],3)),
         'PS4 : \n'+str(round(res[0],3)),'steam_iron : \n'+str(round(res[0],3)),'nespresso_pixie : \n'+str(round(res[0],3)),'atom_pc : \n'+str(round(res[0],3)),
         'toaster : \n'+str(round(res[0],3)), 'home_theatre_amp : \n'+str(round(res[0],3)),'sky_hd_box : \n'+str(round(res[0],3))
          ,'kettle : \n'+str(round(res[0],3)),'fridge_freezer : \n'+str(round(res[0],3)),'oven : \n'+str(round(res[0],3)),'electric_hb : \n'+str(round(res[0],3)),
         'dishwasher : \n'+str(round(res[0],3)),'microwave : \n'+str(round(res[0],3)),'washer_dryer : \n'+str(round(res[0],3)),
         'vacuum_cleanervacuum_cleaner : \n'+str(round(res[0],3))]


res=[h5_ch_2['power_demand'][:14400].mean(),h5_ch_3['power_demand'][:14400].mean(),h5_ch_4['power_demand'][14400].mean(),
     h5_ch_5['power_demand'][:14400].mean(),h5_ch_6['power_demand'][:14400].mean(),h5_ch_7['power_demand'][:14400].mean(),
     h5_ch_8['power_demand'][:14400].mean(),h5_ch_9['power_demand'][:14400].mean(),h5_ch_10['power_demand'][:14400].mean(),
     h5_ch_11['power_demand'][:14400].mean(),h5_ch_12['power_demand'][:14400].mean(),h5_ch_13['power_demand'][:14400].mean(),
     h5_ch_14['power_demand'][:14400].mean(),h5_ch_15['power_demand'][:14400].mean(),h5_ch_16['power_demand'][:14400].mean()
     ,h5_ch_17['power_demand'][:14400].mean(),h5_ch_18['power_demand'][:14400].mean(),h5_ch_19['power_demand'][:14400].mean(),
     h5_ch_20['power_demand'][:14400].mean(),h5_ch_21['power_demand'][:14400].mean(),h5_ch_22['power_demand'][:14400].mean(),
     h5_ch_23['power_demand'][:14400].mean(),h5_ch_24['power_demand'][:14400].mean(),h5_ch_25['power_demand'][:14400].mean()]

x = [i for i in range(1,25)]
plt.figure(figsize=(18,5))
plt.bar(x,res)
plt.xticks(x, labels,rotation=45)
plt.ylabel('Mean_power_demand')
plt.xlabel('Appliances')
plt.title('Power_demand of Appliances in One Day')
# Out:
# Text(0.5, 1.0, 'Power_demand of Appliances in One Day')

# %% [markdown]
# ###Append Appliance Column

# %%
ch2_la = pd.DataFrame({'Appliances': (np.ones(len(h5_ch_2['power_demand']),dtype=np.int8)*2)})
ch3_la = pd.DataFrame({'Appliances': (np.ones(len(h5_ch_3['power_demand']),dtype=np.int8)*3)})
ch4_la = pd.DataFrame({'Appliances': (np.ones(len(h5_ch_4['power_demand']),dtype=np.int8)*4)})
ch5_la = pd.DataFrame({'Appliances': (np.ones(len(h5_ch_5['power_demand']),dtype=np.int8)*5)})
ch6_la = pd.DataFrame({'Appliances': (np.ones(len(h5_ch_6['power_demand']),dtype=np.int8)*6)})
ch7_la = pd.DataFrame({'Appliances': (np.ones(len(h5_ch_7['power_demand']),dtype=np.int8)*7)})
ch8_la = pd.DataFrame({'Appliances': (np.ones(len(h5_ch_8['power_demand']),dtype=np.int8)*8)})
ch9_la = pd.DataFrame({'Appliances': (np.ones(len(h5_ch_9['power_demand']),dtype=np.int8)*9)})
ch10_la = pd.DataFrame({'Appliances': (np.ones(len(h5_ch_10['power_demand']),dtype=np.int8)*10)})
ch11_la = pd.DataFrame({'Appliances': (np.ones(len(h5_ch_11['power_demand']),dtype=np.int8)*11)})
ch12_la = pd.DataFrame({'Appliances': (np.ones(len(h5_ch_12['power_demand']),dtype=np.int8)*12)})
ch13_la = pd.DataFrame({'Appliances': (np.ones(len(h5_ch_13['power_demand']),dtype=np.int8)*13)})
ch14_la = pd.DataFrame({'Appliances': (np.ones(len(h5_ch_14['power_demand']),dtype=np.int8)*14)})
ch15_la = pd.DataFrame({'Appliances': (np.ones(len(h5_ch_15['power_demand']),dtype=np.int8)*15)})
ch16_la = pd.DataFrame({'Appliances': (np.ones(len(h5_ch_16['power_demand']),dtype=np.int8)*16)})
ch17_la = pd.DataFrame({'Appliances': (np.ones(len(h5_ch_17['power_demand']),dtype=np.int8)*17)})
ch18_la = pd.DataFrame({'Appliances': (np.ones(len(h5_ch_18['power_demand']),dtype=np.int8)*18)})
ch19_la = pd.DataFrame({'Appliances': (np.ones(len(h5_ch_19['power_demand']),dtype=np.int8)*19)})
ch20_la = pd.DataFrame({'Appliances': (np.ones(len(h5_ch_20['power_demand']),dtype=np.int8)*20)})
ch21_la = pd.DataFrame({'Appliances': (np.ones(len(h5_ch_21['power_demand']),dtype=np.int8)*21)})
ch22_la = pd.DataFrame({'Appliances': (np.ones(len(h5_ch_22['power_demand']),dtype=np.int8)*22)})
ch23_la = pd.DataFrame({'Appliances': (np.ones(len(h5_ch_23['power_demand']),dtype=np.int8)*23)})
ch24_la = pd.DataFrame({'Appliances': (np.ones(len(h5_ch_24['power_demand']),dtype=np.int8)*24)})
ch25_la = pd.DataFrame({'Appliances': (np.ones(len(h5_ch_25['power_demand']),dtype=np.int8)*25)})


h5_ch_2=h5_ch_2.join(ch2_la)
h5_ch_3=h5_ch_3.join(ch3_la)
h5_ch_4=h5_ch_4.join(ch4_la)
h5_ch_5=h5_ch_5.join(ch5_la)
h5_ch_6=h5_ch_6.join(ch6_la)
h5_ch_7=h5_ch_7.join(ch7_la)
h5_ch_8=h5_ch_8.join(ch8_la)
h5_ch_9=h5_ch_9.join(ch9_la)
h5_ch_10=h5_ch_10.join(ch10_la)
h5_ch_11=h5_ch_11.join(ch11_la)
h5_ch_12=h5_ch_12.join(ch12_la)
h5_ch_13=h5_ch_13.join(ch13_la)
h5_ch_14=h5_ch_14.join(ch14_la)
h5_ch_15=h5_ch_15.join(ch15_la)
h5_ch_16=h5_ch_16.join(ch16_la)
h5_ch_17=h5_ch_17.join(ch17_la)
h5_ch_18=h5_ch_18.join(ch18_la)
h5_ch_19=h5_ch_19.join(ch19_la)
h5_ch_20=h5_ch_20.join(ch20_la)
h5_ch_21=h5_ch_21.join(ch21_la)
h5_ch_22=h5_ch_22.join(ch22_la)
h5_ch_23=h5_ch_23.join(ch23_la)
h5_ch_24=h5_ch_24.join(ch24_la)
h5_ch_25=h5_ch_25.join(ch25_la)



h5_ch_4.head(4)
# Out:
#                  time  power_demand  Appliances
# 0 2014-06-29 16:23:51             0           4
# 1 2014-06-29 16:23:57             0           4
# 2 2014-06-29 16:24:03             0           4
# 3 2014-06-29 16:24:09             1           4

# %% [markdown]
# ###Append  On / Off Column

# %%
print("channel 2 - > \t Maximum power demand : "+str(max(h5_ch_2['power_demand'])),"\t Minimum power demand : "+str(min(h5_ch_2['power_demand'])))
print("channel 3 - > \t Maximum power demand : "+str(max(h5_ch_3['power_demand'])),"\t Minimum power demand : "+str(min(h5_ch_3['power_demand'])))
print("channel 4 - > \t Maximum power demand : "+str(max(h5_ch_4['power_demand'])),"\t Minimum power demand : "+str(min(h5_ch_4['power_demand'])))
print("channel 5 - > \t Maximum power demand : "+str(max(h5_ch_5['power_demand'])),"\t Minimum power demand : "+str(min(h5_ch_5['power_demand'])))
print("channel 6 - > \t Maximum power demand : "+str(max(h5_ch_6['power_demand'])),"\t Minimum power demand : "+str(min(h5_ch_6['power_demand'])))
print("channel 7 - > \t Maximum power demand : "+str(max(h5_ch_7['power_demand'])),"\t Minimum power demand : "+str(min(h5_ch_7['power_demand'])))
print("channel 8 - > \t Maximum power demand : "+str(max(h5_ch_8['power_demand'])),"\t Minimum power demand : "+str(min(h5_ch_8['power_demand'])))
print("channel 9 - > \t Maximum power demand : "+str(max(h5_ch_9['power_demand'])),"\t Minimum power demand : "+str(min(h5_ch_9['power_demand'])))
print("channel 10 - > \t Maximum power demand : "+str(max(h5_ch_10['power_demand'])),"\t Minimum power demand : "+str(min(h5_ch_10['power_demand'])))
print("channel 11 - > \t Maximum power demand : "+str(max(h5_ch_11['power_demand'])),"\t Minimum power demand : "+str(min(h5_ch_11['power_demand'])))
print("channel 12 - > \t Maximum power demand : "+str(max(h5_ch_12['power_demand'])),"\t Minimum power demand : "+str(min(h5_ch_12['power_demand'])))
print("channel 13 - > \t Maximum power demand : "+str(max(h5_ch_13['power_demand'])),"\t Minimum power demand : "+str(min(h5_ch_13['power_demand'])))
print("channel 14 - > \t Maximum power demand : "+str(max(h5_ch_14['power_demand'])),"\t Minimum power demand : "+str(min(h5_ch_14['power_demand'])))
print("channel 15 - > \t Maximum power demand : "+str(max(h5_ch_15['power_demand'])),"\t Minimum power demand : "+str(min(h5_ch_15['power_demand'])))
print("channel 16 - > \t Maximum power demand : "+str(max(h5_ch_16['power_demand'])),"\t Minimum power demand : "+str(min(h5_ch_16['power_demand'])))
print("channel 17 - > \t Maximum power demand : "+str(max(h5_ch_17['power_demand'])),"\t Minimum power demand : "+str(min(h5_ch_17['power_demand'])))
print("channel 18 - > \t Maximum power demand : "+str(max(h5_ch_18['power_demand'])),"\t Minimum power demand : "+str(min(h5_ch_18['power_demand'])))
print("channel 19 - > \t Maximum power demand : "+str(max(h5_ch_19['power_demand'])),"\t Minimum power demand : "+str(min(h5_ch_19['power_demand'])))
print("channel 20 - > \t Maximum power demand : "+str(max(h5_ch_20['power_demand'])),"\t Minimum power demand : "+str(min(h5_ch_20['power_demand'])))
print("channel 21 - > \t Maximum power demand : "+str(max(h5_ch_21['power_demand'])),"\t Minimum power demand : "+str(min(h5_ch_21['power_demand'])))
print("channel 22 - > \t Maximum power demand : "+str(max(h5_ch_22['power_demand'])),"\t Minimum power demand : "+str(min(h5_ch_22['power_demand'])))
print("channel 23 - > \t Maximum power demand : "+str(max(h5_ch_23['power_demand'])),"\t Minimum power demand : "+str(min(h5_ch_23['power_demand'])))
print("channel 24 - > \t Maximum power demand : "+str(max(h5_ch_24['power_demand'])),"\t Minimum power demand : "+str(min(h5_ch_24['power_demand'])))
print("channel 25 - > \t Maximum power demand : "+str(max(h5_ch_25['power_demand'])),"\t Minimum power demand : "+str(min(h5_ch_25['power_demand'])))
# Out:
# channel 2 - > 	 Maximum power demand : 135 	 Minimum power demand : 0
# channel 3 - > 	 Maximum power demand : 3510 	 Minimum power demand : 0
# channel 4 - > 	 Maximum power demand : 3401 	 Minimum power demand : 0
# channel 5 - > 	 Maximum power demand : 1664 	 Minimum power demand : 0
# channel 6 - > 	 Maximum power demand : 543 	 Minimum power demand : 0
# channel 7 - > 	 Maximum power demand : 3289 	 Minimum power demand : 0
# channel 8 - > 	 Maximum power demand : 50 	 Minimum power demand : 0
# channel 9 - > 	 Maximum power demand : 2054 	 Minimum power demand : 0
# channel 10 - > 	 Maximum power demand : 1224 	 Minimum power demand : 0
# channel 11 - > 	 Maximum power demand : 2 	 Minimum power demand : 0
# channel 12 - > 	 Maximum power demand : 3056 	 Minimum power demand : 0
# channel 13 - > 	 Maximum power demand : 2123 	 Minimum power demand : 0
# channel 14 - > 	 Maximum power demand : 55 	 Minimum power demand : 21
# ...

# %%
ch2_l = pd.DataFrame({'On/Off': h5_ch_2['power_demand']>5})
ch3_l = pd.DataFrame({'On/Off': h5_ch_3['power_demand']>5})
ch4_l = pd.DataFrame({'On/Off': h5_ch_4['power_demand']>5})
ch5_l = pd.DataFrame({'On/Off': h5_ch_5['power_demand']>5})
ch6_l = pd.DataFrame({'On/Off': h5_ch_6['power_demand']>5})
ch7_l = pd.DataFrame({'On/Off': h5_ch_7['power_demand']>5})
ch8_l = pd.DataFrame({'On/Off': h5_ch_8['power_demand']>5})
ch9_l = pd.DataFrame({'On/Off': h5_ch_9['power_demand']>5})
ch10_l = pd.DataFrame({'On/Off': h5_ch_10['power_demand']>5})
ch11_l = pd.DataFrame({'On/Off': h5_ch_11['power_demand']>0})
ch12_l = pd.DataFrame({'On/Off': h5_ch_12['power_demand']>5})
ch13_l = pd.DataFrame({'On/Off': h5_ch_13['power_demand']>5})
ch14_l = pd.DataFrame({'On/Off': h5_ch_14['power_demand']>25})
ch15_l = pd.DataFrame({'On/Off': h5_ch_15['power_demand']>5})
ch16_l = pd.DataFrame({'On/Off': h5_ch_16['power_demand']>5})
ch17_l = pd.DataFrame({'On/Off': h5_ch_17['power_demand']>5})
ch18_l = pd.DataFrame({'On/Off': h5_ch_18['power_demand']>5})
ch19_l = pd.DataFrame({'On/Off': h5_ch_19['power_demand']>5})
ch20_l = pd.DataFrame({'On/Off': h5_ch_20['power_demand']>10})
ch21_l = pd.DataFrame({'On/Off': h5_ch_21['power_demand']>5})
ch22_l = pd.DataFrame({'On/Off': h5_ch_22['power_demand']>5})
ch23_l = pd.DataFrame({'On/Off': h5_ch_23['power_demand']>5})
ch24_l = pd.DataFrame({'On/Off': h5_ch_24['power_demand']>5})
ch25_l = pd.DataFrame({'On/Off': h5_ch_25['power_demand']>5})

h5_ch_2=h5_ch_2.join(ch2_l)
h5_ch_3=h5_ch_3.join(ch3_l)
h5_ch_4=h5_ch_4.join(ch4_l)
h5_ch_5=h5_ch_5.join(ch5_l)
h5_ch_6=h5_ch_6.join(ch6_l)
h5_ch_7=h5_ch_7.join(ch7_l)
h5_ch_8=h5_ch_8.join(ch8_l)
h5_ch_9=h5_ch_9.join(ch9_l)
h5_ch_10=h5_ch_10.join(ch10_l)
h5_ch_11=h5_ch_11.join(ch11_l)
h5_ch_12=h5_ch_12.join(ch12_l)
h5_ch_13=h5_ch_13.join(ch13_l)
h5_ch_14=h5_ch_14.join(ch14_l)
h5_ch_15=h5_ch_15.join(ch15_l)
h5_ch_16=h5_ch_16.join(ch16_l)
h5_ch_17=h5_ch_17.join(ch17_l)
h5_ch_18=h5_ch_18.join(ch18_l)
h5_ch_19=h5_ch_19.join(ch19_l)
h5_ch_20=h5_ch_20.join(ch20_l)
h5_ch_21=h5_ch_21.join(ch21_l)
h5_ch_22=h5_ch_22.join(ch22_l)
h5_ch_23=h5_ch_23.join(ch23_l)
h5_ch_24=h5_ch_24.join(ch24_l)
h5_ch_25=h5_ch_25.join(ch25_l)

h5_ch_14.tail(4)
# Out:
#                       time  power_demand  Appliances  On/Off
# 985994 2014-09-07 14:17:35            23          14   False
# 985995 2014-09-07 14:17:42            24          14   False
# 985996 2014-09-07 14:17:49            24          14   False
# 985997 2014-09-07 14:17:56            24          14   False

# %%
h5_ch_24.head(4)
# Out:
#                  time  power_demand  Appliances  On/Off
# 0 2014-06-29 16:23:56           225          24    True
# 1 2014-06-29 16:24:02           262          24    True
# 2 2014-06-29 16:24:08           219          24    True
# 3 2014-06-29 16:24:14           236          24    True

# %%
h5_data=[h5_ch_2,h5_ch_3,h5_ch_4,h5_ch_5,h5_ch_6,h5_ch_7,h5_ch_8,h5_ch_9,h5_ch_10,h5_ch_11,h5_ch_12,h5_ch_13,
         h5_ch_14,h5_ch_15,h5_ch_16,h5_ch_17,h5_ch_18,h5_ch_19,h5_ch_20,h5_ch_21,h5_ch_22,h5_ch_23,h5_ch_24,h5_ch_25]
h5_data=pd.concat(h5_data,ignore_index= True)

# %%
h5_data.head(4)
# Out:
#                  time  power_demand  Appliances  On/Off
# 0 2014-06-29 16:23:50             1           2   False
# 1 2014-06-29 16:23:56             1           2   False
# 2 2014-06-29 16:24:03             1           2   False
# 3 2014-06-29 16:24:09             1           2   False

# %%
h5_data=h5_data.sort_values('time')

# %%
h5_data.head(4)
# Out:
#                         time  power_demand  Appliances  On/Off
# 0        2014-06-29 16:23:50             1           2   False
# 6525451  2014-06-29 16:23:50             0           6   False
# 15050548 2014-06-29 16:23:50             0          13   False
# 20953704 2014-06-29 16:23:50           108          19    True

# %%
print(len(h5_data))
# Out:
# 32140890

# %% [markdown]
# #Power Forecast

# %%
h5_data_edit=pd.DataFrame(columns=['time','power_demand'])
i=0
while (i < len(h5_data)):
  app=[]
  star=h5_data.iloc[i,0]
  end=h5_data.iloc[i,0]+datetime.timedelta(minutes=30)
  j=i+1
  while (j<len(h5_data)and h5_data.iloc[j,0]<end ):
    if (h5_data.iloc[j,3]==True):
      app.append(h5_data.iloc[j,1])
    j+=1
  new_row=pd.Series({'time':star,'power_demand':sum(app)})
  h5_data_edit = h5_data_edit.append(new_row,ignore_index=True)
  i=j+1

# %%
h5_data_edit
# Out:
#                     time power_demand
# 0    2014-06-29 16:23:50       275264
# 1    2014-06-29 16:53:50       142084
# 2    2014-06-29 17:23:50       208483
# 3    2014-06-29 17:53:50       369282
# 4    2014-06-29 18:23:51       283304
# ...                  ...          ...
# 6332 2014-11-13 15:38:32        75050
# 6333 2014-11-13 16:08:36       254801
# 6334 2014-11-13 16:38:37       139522
# 6335 2014-11-13 17:08:38       134427
# 6336 2014-11-13 17:38:39        64144
#
# [6337 rows x 2 columns]

# %%
h5_data_edit['date']=pd.to_datetime(h5_data_edit['time'])
data=h5_data_edit.iloc[:,[1]]
data=data.set_index(h5_data_edit.date)
data['power_demand']=pd.to_numeric(data['power_demand'],downcast='float',errors='coerce')

# %%
data.head(4)
# Out:
#                      power_demand
# date
# 2014-06-29 16:23:50      275264.0
# 2014-06-29 16:53:50      142084.0
# 2014-06-29 17:23:50      208483.0
# 2014-06-29 17:53:50      369282.0

# %%
data.plot()

# %% [markdown]
# ###Resample

# %%
hourly=data.resample('H').sum()
plt.plot(hourly)

# %%
df=hourly
df.reset_index(inplace=True)
df.head()
# Out:
#                  date  power_demand
# 0 2014-06-29 16:00:00      417348.0
# 1 2014-06-29 17:00:00      577765.0
# 2 2014-06-29 18:00:00      417081.0
# 3 2014-06-29 19:00:00      253306.0
# 4 2014-06-29 20:00:00      231882.0

# %%
df=df.rename(columns={'date':'ds','power_demand':'y'})
df.head()
# Out:
#                    ds         y
# 0 2014-06-29 16:00:00  417348.0
# 1 2014-06-29 17:00:00  577765.0
# 2 2014-06-29 18:00:00  417081.0
# 3 2014-06-29 19:00:00  253306.0
# 4 2014-06-29 20:00:00  231882.0

# %% [markdown]
# #Model 1 - > Prophet

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(df['ds'],df['y'],test_size=0.2)

# %%
df_tr={'ds':X_train,'y':y_train}
df_te={'ds':X_test,'y':y_test}
df_train=pd.DataFrame(data=df_tr)
df_test=pd.DataFrame(data=df_te)

# %%
import fbprophet
df_prophet=fbprophet.Prophet(changepoint_prior_scale=0.10)
df_prophet.fit(df_train)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
df_for=df_prophet.make_future_dataframe(periods=4,freq='H')
df_for=df_prophet.predict(df_for)

# %%
df_for=df_prophet.predict(df_test)

# %% [markdown]
# #Model 2 - >  SVM

# %%
hourly=data.resample('H').sum()
plt.plot(hourly)

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df =pd.DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = pd.concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
values = hourly.values
values = values.astype('float32')
scaler = MinMaxScaler(feature_range=(0,1))
scaled = scaler.fit_transform(values)
n_mins = 5
n_features = 1
reframed = series_to_supervised(scaled, n_mins, 1)
print(reframed.shape)
# Out:
# (3285, 6)

# %%
# split into train and test sets
values = reframed.values
n_train_mins =2500
train = values[:n_train_mins, :]
test = values[n_train_mins:, :]
# split into input and outputs
n_obs = n_mins * n_features
train_X, train_y = train[:, :n_obs], train[:, -1]
test_X,  test_y =test[:, :n_obs], test[:,-1]
#print(train_y,test_y)
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (2500, 5) (2500,) (785, 5) (785,)

# %%
# design svm model
clf = SVR(gamma='scale')

# fit model
clf.fit(train_X,train_y)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
# make a prediction
predict_y = clf.predict(test_X)
yhat = predict_y.reshape(predict_y.shape[0],1)
test_X = test_X.reshape((test_X.shape[0],n_mins*n_features))
print(yhat.shape,test_X.shape)
# Out:
# (785, 1) (785, 5)

# %%
# invert scaling for forecast
inv_yhat = np.concatenate((test_X[:, -24:-1], yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,-1]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_X[:, -24:-1], test_y), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,-1]

# %%
ypred=clf.predict(test_X)

# %% [markdown]
# #Model 3 ->  LSTM

# %%
hourly=data.resample('H').sum()
plt.plot(hourly)

# %%
#  convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = pd.DataFrame(data)
	cols, names = list(), list()
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	agg = pd.concat(cols, axis=1)
	agg.columns = names
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
values = hourly.values
values = values.astype('float32')
scaler = MinMaxScaler(feature_range=(0,1))
scaled = scaler.fit_transform(values)
n_mins = 5
n_features = 1
reframed = series_to_supervised(scaled, n_mins, 1)
print(reframed.shape)
print(reframed.head())
# Out:
# (3285, 6)
#    var1(t-5)  var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)   var1(t)
# 5   0.306900   0.424864   0.306704   0.186271   0.170516  0.169519
# 6   0.424864   0.306704   0.186271   0.170516   0.169519  0.133282
# 7   0.306704   0.186271   0.170516   0.169519   0.133282  0.133352
# 8   0.186271   0.170516   0.169519   0.133282   0.133352  0.131640
# 9   0.170516   0.169519   0.133282   0.133352   0.131640  0.131548

# %%
values = reframed.values
n_train_mins =2500
train = values[:n_train_mins, :]
test = values[n_train_mins:, :]
n_obs = n_mins * n_features
train_X, train_y = train[:, :n_obs], train[:, -1]
test_X,  test_y =test[:, :n_obs], test[:,-1]
train_X = train_X.reshape((train_X.shape[0], n_mins, n_features))
test_X = test_X.reshape((test_X.shape[0], n_mins, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (2500, 5, 1) (2500,) (785, 5, 1) (785,)

# %%
# Build Model
from keras.models import Sequential
from keras.layers import Dense,Dropout,LSTM,Activation
layers = [0,120,0,0,1]
model = Sequential()

model.add(LSTM(
	layers[1],
	input_shape=(train_X.shape[1], train_X.shape[2]),
	return_sequences=False))
model.add(Dropout(0.5))
model.add(Dense(layers[4]))
model.add(Activation("linear"))

model.compile(loss='mae', optimizer='adam')

# %%
# Train network
history = model.fit(train_X, train_y, epochs = 50, batch_size=100, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Train on 2500 samples, validate on 785 samples
# Epoch 1/50
#  - 2s - loss: 0.0969 - val_loss: 0.0518
# Epoch 2/50
#  - 0s - loss: 0.0693 - val_loss: 0.0556
# Epoch 3/50
#  - 0s - loss: 0.0634 - val_loss: 0.0521
# Epoch 4/50
#  - 0s - loss: 0.0634 - val_loss: 0.0509
# Epoch 5/50
#  - 0s - loss: 0.0620 - val_loss: 0.0490
# Epoch 6/50
#  - 0s - loss: 0.0634 - val_loss: 0.0510
# Epoch 7/50
#  - 0s - loss: 0.0604 - val_loss: 0.0496
# Epoch 8/50
#  - 0s - loss: 0.0601 - val_loss: 0.0488
# Epoch 9/50
#  - 0s - loss: 0.0602 - val_loss: 0.0481
# Epoch 10/50
#  - 0s - loss: 0.0595 - val_loss: 0.0475
# Epoch 11/50
#  - 0s - loss: 0.0594 - val_loss: 0.0472
# Epoch 12/50
#  - 0s - loss: 0.0585 - val_loss: 0.0472
# Epoch 13/50
#  - 0s - loss: 0.0582 - val_loss: 0.0474
# Epoch 14/50
#  - 0s - loss: 0.0568 - val_loss: 0.0463
# Epoch 15/50
#  - 0s - loss: 0.0566 - val_loss: 0.0458
# Epoch 16/50
#  - 0s - loss: 0.0564 - val_loss: 0.0453
# Epoch 17/50
#  - 0s - loss: 0.0560 - val_loss: 0.0458
# ...

# %%
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
yhat_ = model.predict(test_X)

# %%
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0],n_mins*n_features))
print(yhat.shape,test_X.shape)
# invert scaling for forecast
inv_yhat_ = np.concatenate((test_X[:, -24:-1], yhat), axis=1)
inv_yhat_ = scaler.inverse_transform(inv_yhat_)
inv_yhat_ = inv_yhat_[:,-1]

# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y_ = np.concatenate((test_X[:, -24:-1], test_y), axis=1)
inv_y_ = scaler.inverse_transform(inv_y_)
inv_y_ = inv_y_[:,-1]
# Out:
# (785, 1) (785, 5)

# %% [markdown]
# # Evalution Of All Model For Forcast

# %% [markdown]
# ##Model 1

# %% [markdown]
# ### very bad model

# %%
#To RMSE:
ytrue=df_test['y'].to_list()
yhat=df_for['yhat_upper'].to_list()
print("RMSE: %.2f" %np.sqrt(metrics.mean_squared_error(ytrue, yhat)))
# Out:
# RMSE: 236601.65

# %% [markdown]
# ## Model 2

# %% [markdown]
# ### Good model

# %%
# calculate RMSE
print("RMSE: %.2f" %np.sqrt(metrics.mean_squared_error(test_y, ypred)))
# Out:
# RMSE: 0.11

# %%
#calculate accuarcy 
accuracy=(1-np.sqrt(metrics.mean_squared_error(test_y, ypred))) *100
print('Accuracy : ',accuracy)
# Out:
# Accuracy :  89.26728418952219

# %% [markdown]
# ## Model 3

# %% [markdown]
# ### perfect model

# %%
# calculate RMSE
print("RMSE: %.2f" % np.sqrt(metrics.mean_squared_error(test_y, yhat_)))
# Out:
# RMSE: 0.08

# %%
#calculate accuarcy 
accuracy=(1- np.sqrt(metrics.mean_squared_error(test_y, yhat_))) *100
print('Accuracy : ',accuracy)
# Out:
# Accuracy :  91.63133576512337

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Model 1

# %%
#plt 
plt.figure(figsize=(20,30))
df_prophet.plot(df_for,xlabel='date',ylabel='Power_Consumption')
plt.title("On Test Data")
# Out:
# Text(0.5, 1, 'On Test Data')

# %% [markdown]
# ## Model 2

# %%
# plot 
plt.figure(figsize=(18,6))
plt.plot([x for x in range(1, inv_yhat.shape[0]+1)], inv_yhat, linestyle='-', color='red', label='prediction')
plt.plot([x for x in range(1, inv_y.shape[0]+1)], inv_y, linestyle='-', color='blue', label='actual')
plt.legend(loc=1, prop={'size': 12})
plt.show()

# %% [markdown]
# ## Model 3

# %%
index = [0,100,200,300,400,500,600,700,800,900]
# plot
plt.figure(figsize=(18,6))
plt.plot([x for x in range(1,inv_yhat_.shape[0]+1)], inv_yhat_, linestyle='-', color='red', label='prediction')
plt.plot([x for x in range(1,inv_y_.shape[0]+1)], inv_y_, linestyle='-', color='blue', label='actual')
plt.legend(loc=1, prop={'size': 12})
plt.show()

# %% [markdown]
# #Association Rule

# %% [markdown]
# ###perprocessing

# %%
h5_data_edit=pd.DataFrame(columns=['starttime','endtime','Active_Appliances'])
i=0
while (i < len(h5_data)):
  app=[]
  star=h5_data.iloc[i,0]
  end=h5_data.iloc[i,0]+datetime.timedelta(minutes=30)
  j=i+1
  while (j<len(h5_data)and h5_data.iloc[j,0]<end ):
    if (h5_data.iloc[j,3]==True):
      app.append(str(h5_data.iloc[j,2]))
    j+=1
  new_row=pd.Series({'starttime':star,'endtime':end,'Active_Appliances':set(app)})
  h5_data_edit = h5_data_edit.append(new_row,ignore_index=True)
  i=j+1

# %%
print(star,end,set(app))
# Out:
# 2014-11-13 17:38:39 2014-11-13 18:08:39 {'23', '24', '3', '9', '20'}

# %% [markdown]
# ###Apriori Algorithm

# %%
Appliances=[]
for i in range(len(h5_data_edit)):
  Appliances.append(list(h5_data_edit.iloc[i,2]))

# %%
rules=apriori(Appliances,min_support=0.4,min_length=2)

# %%
result=list(rules)

# %% [markdown]
# ##Visulizing Appliances Association

# %%
result_list=[]
for i in range(len(result)-1):
  if (len(result[i][0])>1):
    print('Rule : '+str(result[i][0]))
    print("Support : "+str(result[i][1]))
    if (len(result[i][0])==2):
      [h,_]=result[i][2]
      [_,_,co,le]=h
      print("Confidence : " +str(co)+ "  Left : "+str(le))
    elif (len(result[i][0])==3):
      [_,h,_]=result[i][2]
      [_,_,co,le]=h
      print("Confidence : " +str(co)+ "  Left : "+str(le))
    elif (len(result[i][0])==4):
      [_,_,h,_]=result[i][2]
      [_,_,co,le]=h
      print("Confidence : " +str(co)+ "  Left : "+str(le))
    elif (len(result[i][0])==5):
      [_,_,h,_,_]=result[i][2]
      [_,_,co,le]=h
      print("Confidence : " +str(co)+ "  Left : "+str(le))
    elif (len(result[i][0])==6):
      [_,_,h,_,_,_]=result[i][2]
      [_,_,co,le]=h
      print("Confidence : " +str(co)+ "  Left : "+str(le))   
    elif (len(result[i][0])==7):
      [_,_,h,_,_,_,_]=result[i][2]
      [_,_,co,le]=h
      print("Confidence : " +str(co)+ "  Left : "+str(le))     
    elif (len(result[i][0])==8):
      [_,_,h,_,_,_,_,_]=result[i][2]
      [_,_,co,le]=h
      print("Confidence : " +str(co)+ "  Left : "+str(le)) 
    elif (len(result[i][0])==8):
      [_,_,h,_,_,_,_,_,_]=result[i][2]
      [_,_,co,le]=h
      print("Confidence : " +str(co)+ "  Left : "+str(le))       
    print('-------------------------------------')
for i in range(1,len(h5_labels)):
  print('where '+ str(i)+ ' -> '+str(h5_labels.iloc[i,1]))
# Out:
# Rule : frozenset({'14', '16'})
# Support : 0.5010257219504497
# Confidence : 0.9745242480049109  Left : 1.887396136799242
# -------------------------------------
# Rule : frozenset({'17', '14'})
# Support : 0.5139655988638157
# Confidence : 0.9996930632289747  Left : 1.8888058860113333
# -------------------------------------
# Rule : frozenset({'19', '14'})
# Support : 0.45368470885276946
# Confidence : 0.8824432166973603  Left : 1.044265670254187
# -------------------------------------
# Rule : frozenset({'14', '23'})
# Support : 0.45510493924569984
# Confidence : 0.8852056476365867  Left : 0.9875965121607483
# -------------------------------------
# Rule : frozenset({'24', '14'})
# Support : 0.4349061069906896
# Confidence : 0.8459177409453652  Left : 0.9844960008027143
# -------------------------------------
# Rule : frozenset({'14', '3'})
# Support : 0.4229130503392773
# Confidence : 0.8225905463474524  Left : 1.1036960178284578
# -------------------------------------
# ...

# %% [markdown]
# #Frequent Pattern

# %%
h5_data_edit=pd.DataFrame(columns=['starttime','endtime','Active_Appliances'])
i=0
while (i < len(h5_data)):
  app=[]
  star=h5_data.iloc[i,0]
  end=h5_data.iloc[i,0]+datetime.timedelta(minutes=30)
  j=i+1
  while (j<len(h5_data)and h5_data.iloc[j,0]<end ):
    if (h5_data.iloc[j,3]==True):
      app.append(str(h5_data.iloc[j,2]))
    j+=1
  new_row=pd.Series({'starttime':star,'endtime':end,'Active_Appliances':set(app)})
  h5_data_edit = h5_data_edit.append(new_row,ignore_index=True)
  i=j+1

# %% [markdown]
# ## Frequent pattern source data base

# %%
h5_data_edit.head(10)
# Out:
#             starttime  ...                             Active_Appliances
# 0 2014-06-29 16:23:50  ...              {17, 24, 8, 9, 10, 19, 16, 5, 3}
# 1 2014-06-29 16:53:50  ...          {17, 24, 8, 9, 10, 19, 14, 16, 5, 3}
# 2 2014-06-29 17:23:50  ...              {17, 24, 8, 9, 19, 14, 16, 5, 3}
# 3 2014-06-29 17:53:50  ...              {17, 24, 8, 9, 20, 19, 16, 5, 3}
# 4 2014-06-29 18:23:51  ...          {17, 24, 8, 9, 20, 19, 14, 16, 5, 3}
# 5 2014-06-29 18:53:51  ...      {17, 24, 8, 9, 10, 20, 19, 14, 16, 5, 3}
# 6 2014-06-29 19:23:51  ...  {17, 24, 8, 10, 9, 20, 19, 13, 14, 16, 5, 3}
# 7 2014-06-29 19:53:51  ...                  {17, 24, 8, 9, 19, 16, 5, 3}
# 8 2014-06-29 20:23:51  ...              {17, 24, 8, 9, 19, 14, 16, 5, 3}
# 9 2014-06-29 20:53:51  ...                  {17, 24, 8, 9, 19, 16, 5, 3}
#
# [10 rows x 3 columns]

# %%
for i in range(1,len(h5_labels)):
  print('Device '+ str(i)+ ' is '+str(h5_labels.iloc[i,1]))
# Out:
# Device 1 is stereo_speakers_bedroom
# Device 2 is i7_desktop
# Device 3 is hairdryer
# Device 4 is primary_tv
# Device 5 is 24_inch_lcd_bedroom
# Device 6 is treadmill
# Device 7 is network_attached_storage
# Device 8 is core2_server
# Device 9 is 24_inch_lcd
# Device 10 is PS4
# Device 11 is steam_iron
# Device 12 is nespresso_pixie
# Device 13 is atom_pc
# Device 14 is toaster
# Device 15 is home_theatre_amp
# Device 16 is sky_hd_box
# Device 17 is kettle
# Device 18 is fridge_freezer
# Device 19 is oven
# Device 20 is electric_hob
# Device 21 is dishwasher
# Device 22 is microwave
# Device 23 is washer_dryer
# Device 24 is vacuum_cleaner
